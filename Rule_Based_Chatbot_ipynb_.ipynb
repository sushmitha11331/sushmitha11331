# %% [markdown]
# <a href="https://colab.research.google.com/github/sushmitha11331/sushmitha11331/blob/main/Rule_Based_Chatbot_ipynb_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Rule-Based Chatbot
print("🤖 ChatBot: Hi there! I’m your AI assistant. Type 'bye' to exit.\n")

while True:
    user_input = input("You: ").lower()

    if user_input in ["hi", "hello", "hey"]:
        print("🤖 ChatBot: Hello! How can I help you today?")
    elif "name" in user_input:
        print("🤖 ChatBot: I’m a simple AI chatbot created using Python!")
    elif "how are you" in user_input:
        print("🤖 ChatBot: I’m doing great, thanks for asking! How about you?")
    elif "time" in user_input:
        from datetime import datetime
        print("🤖 ChatBot: The current time is", datetime.now().strftime("%H:%M:%S"))
    elif "weather" in user_input:
        print("🤖 ChatBot: I can’t check weather yet, but you can look outside 😉")
    elif "bye" in user_input:
        print("🤖 ChatBot: Goodbye! Have a great day! 👋")
    elif "country" in user_input:
        print("🤖 ChatBot: The biggest country in the world is Russia!")
    elif "mountain" in user_input:
        print("🤖 ChatBot: Mount Everest is the tallest mountain in the world!")
    elif "dessert" in user_input:
        print("🤖 ChatBot: The best dessert depends on taste—but chocolate cake never fails! 🍫")

        break
    else:
        print("🤖 ChatBot: Sorry, I didn’t understand that.")
# Out:
# 🤖 ChatBot: Hi there! I’m your AI assistant. Type 'bye' to exit.
#
# You: hello
# 🤖 ChatBot: Hello! How can I help you today?
# You: best dessert in the world
# 🤖 ChatBot: Sorry, I didn’t understand that.
# You: tall mountain in the worls
# 🤖 ChatBot: Sorry, I didn’t understand that.
# You: biggest country in the world
# 🤖 ChatBot: Sorry, I didn’t understand that.
# You: whats the time
# 🤖 ChatBot: The current time is 13:51:16
